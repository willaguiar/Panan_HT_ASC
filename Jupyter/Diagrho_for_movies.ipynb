# %% [markdown]
# # diag_rho subsampling

# %% [markdown]
# We will [subsample diag_rho to 2 or 3 levels](https://github.com/COSIMA/mom6-panan/issues/49#issuecomment-1840560045), so we canoutput very high frequency output to produce movies

# %%
# %config InlineBackend.figure_format='retina'

import cosima_cookbook as cc
import matplotlib.pyplot as plt
import cmocean as cm
import numpy as np
from dask.distributed import Client
from scipy.interpolate import interp1d

import xarray as xr
import cf_xarray as cfxr

# %%
import sys
import os

# %%
client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:38285' processes=7 threads=28, memory=251.20 GiB>

# %%
diag_rho_original = xr.open_dataset('/g/data/ik11/inputs/mom6/panan/0025deg/20230320/diag_rho2.nc')
# Out:
# 0.3.0

# %% [markdown]
# We want the levels closer to 1037.16, 1037.18, 1037.2

# %%
# desired_levels=[78,79,80,81,82,83]
# diag_rho_reduced=diag_rho_original.isel(nrho=desired_levels)

# %%
desired_levels=[78,79,80,81,82,83,99]
diag_rho_reduced=diag_rho_original.isel(nrho=desired_levels)
diag_rho_reduced['rho2'][6]=1038

# %%
diag_rho_reduced.to_netcdf('/home/156/wf4500/v45_wf4500/panan0025/panan0025_highfreq/mom6-panan/localinput/diag_rho2.nc')
