# %% [markdown]
# # Creating cosima and Intake databases for experiments

# %% [markdown]
# THis is temporary since we dont have all outputs saved on gdata yet.

# %%
import cosima_cookbook as cc

# %%
db = '/home/156/wf4500/databases/access/panan01_rerun_withCSHT.db'
session = cc.database.create_session(db)

# %%
directory_list=['/g/data/g40/wf4500/MOM6/panan01_1999to2001_rerun_with_HTsigma/wf4500/mom6/archive/mom6-panan/']

# %%
cc.database.build_index(directory_list, session)
# Out:
# Indexing experiment: mom6-panan
# ...
# 100%|██████████| 341/341 [00:50<00:00,  6.75it/s]
# 2341

# %% [markdown]
# orther ones

# %%
db = '/home/156/wf4500/databases/access/panan01_original_ol01.db'
session = cc.database.create_session(db)

# %%
directory_list=['/g/data/ol01/outputs/mom6-panan/panant-01-zstar-ACCESSyr2/']

# %%
cc.database.build_index(directory_list, session)
# Out:
# Indexing experiment: panant-01-zstar-ACCESSyr2
# ...
# 100%|██████████| 902/902 [02:07<00:00,  7.10it/s]
# 12902

# %%
db = '/home/156/wf4500/databases/access/panan0025_final_ol01.db'
session = cc.database.create_session(db)

# %%
directory_list=['/g/data/ol01/outputs/mom6-panan/panant-0025-zstar-ACCESSyr2/']

# %%
cc.database.build_index(directory_list, session)
# Out:
# Indexing experiment: panant-0025-zstar-ACCESSyr2
# ...
# 100%|██████████| 509/509 [01:01<00:00,  8.27it/s]
# 5509

# %%
db = '/home/156/wf4500/databases/access/panan005_final_ol01.db'
session = cc.database.create_session(db)

# %%
directory_list=['/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESSyr2/']

# %%
cc.database.build_index(directory_list, session)
# Out:
# Indexing experiment: panant-005-zstar-ACCESSyr2
# ...
# 100%|██████████| 43/43 [00:05<00:00,  8.38it/s]
# 14043

# %% [markdown]
# # Cosima database

# %% [markdown]
# ## Panan005

# %% [markdown]
# First a cookbook database.

# %%
db = '/home/156/wf4500/databases/access/panan005_rerun.db'
session = cc.database.create_session(db)

# %%
directory_list=['/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESSyr2/']

# %%
cc.database.build_index(directory_list, session)
# Out:
# Indexing experiment: panant-005-zstar-ACCESSyr2
# 0

# %% [markdown]
# ## Panan0025

# %%
db = '/home/156/wf4500/databases/access/panan0025_rerun.db'
session = cc.database.create_session(db)

# %%
directory_list=['/scratch/oz91/wf4500/panan0025_rerun_17DEC2024/wf4500/mom6/archive/mom6-panan/']

# %%
cc.database.build_index(directory_list, session)
# Out:
# Indexing experiment: mom6-panan
# 100%|██████████| 761/761 [02:45<00:00,  4.60it/s]
# 761

# %% [markdown]
# ## Panan0025 - HF movies run

# %%
db = '/home/156/wf4500/databases/access/panan0025_movies.db'
session = cc.database.create_session(db)

# %%
directory_list=['/scratch/oz91/wf4500/panan_Hifreq_formovies/wf4500/mom6/archive/mom6-panan/']

# %%
cc.database.build_index(directory_list, session)
# Out:
# Indexing experiment: mom6-panan
# ...
# 100%|██████████| 370/370 [00:42<00:00,  8.62it/s]
# 1370

# %% [markdown]
# ## Panan01 HT

# %% [markdown]
# This is a rerun of panan01, done a while ago, that is equal to the panan01 original, but I added additional heat transport outputs binned into sigma coords and theta!

# %%
db = '/home/156/wf4500/databases/access/panan01_paralelrun_HT.db'
session = cc.database.create_session(db)

# %%
directory_list=['/scratch/oz91/wf4500/panan01_year1999rerun_HTsigma/wf4500/mom6/archive/panan01_yr2000_HTsigma/']

# %%
cc.database.build_index(directory_list, session)
# Out:
# Indexing experiment: panan01_yr2000_HTsigma
# ...
# 100%|██████████| 321/321 [00:36<00:00,  8.69it/s]
# 2321

# %% [markdown]
# # NCI intake database

# %% [markdown]
# To run the code below you have to use the following module directory in ARE '/g/data/xp65/public/modules', and the following module 'conda/analysis3-25.02'

# %%
PATH = '/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESSyr2/'

# %%
from access_nri_intake.source import builders

dir(builders)[0:5]
# Out:
# ...
# ['AccessCm2Builder',
#  'AccessEsm15Builder',
#  'AccessOm2Builder',
#  'BaseBuilder',
#  'Builder']
